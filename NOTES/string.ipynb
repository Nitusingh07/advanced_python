# %%
#len()
#return number of character in a given string
#len(strobj)
s="decode"
print(len(s))
count=0
for i in s:
    count=count+1
print(count)
# Out:
# 6
# 6

# %%
#char(number) - take ascii value as parameter and return character.
num1=66
print(chr(num1))
print(chr(97))
print(chr(98))
# Out:
# B
# a
# b

# %%
#ord(character)- take character as an input and return ascii value
print(ord("a"))
print(ord("/"))
print(ord("A"))
print(ord("-"))
# Out:
# 97
# 47
# 65
# 45

# %%
#max()
#min()
s="decode"
print(max(s))
print(min(s))
# Out:
# o
# c

# %%
s="decode"
max_value=s[0]
for i in s:
    if i>max_value:
        max_value=i
print(max_value)
# Out:
# o

# %%
s="decode"
min_value=s[0]
for i in s:
    if i<min_value:
        min_value=i
print(min_value)
# Out:
# c

# %%
s="welcome to the city of lakes"
vowel=0
space=0
consonant=0
for i in s:
    if i in "aeiou":
        vowel=vowel+1
    elif i==" ":
        space=space+1
    else:
        consonant=consonant+1
print(vowel)
print(space)
print(consonant)
# Out:
# 9
# 5
# 14

# %%
n=5
for i in range(n):
    for j in range(i+1):
        print(chr(65+j),end=" ")
    print()
# Out:
# A
# A B
# A B C
# A B C D
# A B C D E

# %%
#upper() - strobj-upper()
#lower() - strobj-upper()
#title() - strobj-upper()
#capitalise()

# %%
n=5
for i in range(n):
    for j in range(i,-1,-1):
        print(chr(65+j),end=" ")
    print()
# Out:
# A
# B A
# C B A
# D C B A
# E D C B A

# %%
n=5
for i in range(n):
    for j in range(i,-1,-1):
        print(chr(68+j),end=" ")
    print()
# Out:
# D
# E D
# F E D
# G F E D
# H G F E D

# %%
n=5
for i in range(n):
    for j in range(i,-1,-1):
        print(chr(65+j),end=" ")
    print()
# Out:
# A
# B A
# C B A
# D C B A
# E D C B A

# %%
#replace 
#strobd.replace (oldstring,newstring,[count])
s = "welcome to bhopal"
print(s.replace("bhopal", "decode"))
print(s.replace("o", "a"))
# Out:
# welcome to decode
# welcame ta bhapal

# %%
#split
#strobj.([seperator],[maxsplit])
#by default - whitespace ,maxsplit-max no of seperator
# split always return list of strings 
s = "welcome to city of lakes"
print(s.split())
print(s.split(" ",4))
print(s.split(" "))
# Out:
# ['welcome', 'to', 'city', 'of', 'lakes']
# ['welcome', 'to', 'city', 'of', 'lakes']
# ['welcome', 'to', 'city', 'of', 'lakes']

# %%
#join 
#seperator.join(s)
s=["welcome", "to", "bhopal"]
s1 =" ".join(s)
print(s1)
# Out:
# welcome to bhopal

# %%
s="hello"
s1="-".join(s)
print(s1)
s2=s1.split("-")
print(s2)
s3=" ".join(s2)
print(s3)
# Out:
# h-e-l-l-o
# ['h', 'e', 'l', 'l', 'o']
# h e l l o

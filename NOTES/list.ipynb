# %%
#list
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[10,20,30,"hello",10.5]
print(l)
print(type(l))
print(l[0])   #indexed
l[0]=1000
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5]
# <class 'list'>
# 10
# [1000, 20, 30, 'hello', 10.5]

# %%
#indexing & slicing
l=[10,20,30,"hello",10.5,1000,200,300,100]
print(l[3])
print(l[3][1])
print(l[-3])
print(l[::-1])
print(l[::])
print(l[::])
print(l[::-1])
print(l[:6:2])
# Out:
# hello
# e
# 200
# [100, 300, 200, 1000, 10.5, 'hello', 30, 20, 10]
# [10, 20, 30, 'hello', 10.5, 1000, 200, 300, 100]

# %%
l=[10,20,30,"hello",1000,10.5,11]
for i in l:
     print(i)
# Out:
# 10
# 20
# 30
# hello
# 1000
# 10.5
# 11

# %%
#methods
#add element to an existing list
#append
# listobj.append (value/obj)
#append method add new element at last position 
l=[10,20,30,"hello",10.5]
l.append(1000)
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 1000]

# %%
l=[10,20,30,"hello",10.5]
l.append([100,200,300])
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, [100, 200, 300]]

# %%
l=[100,23,34,11,17,32,35,98,7]
l1=[]
for i in l:
    if i%2==0:
        l1.append(i)
print(l1)
# Out:
# [100, 34, 32, 98]

# %%
l=[]
for i in range(0,8,2):
    l.append(chr(65+i))
    print(l1)

# %%
l=[]
for i in range(2,11,2):

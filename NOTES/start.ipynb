# %%
print("hello, python!")
# Out:
# hello, python!

# %%
name = "Nitu"
age = 20
height = 5.4

# %%
age=int(input("any number"))
if age>=20:
    print("adult")
else:
    print("minor")
# Out:
# any number 10
# minor

# %%
for i in range ( 1,6) :
    print (i )
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 2
while i <= 8:
    print(i)
    i += 3
# Out:
# 2
# 5
# 8

# %%
def greet(name):
    print("Hello", name)

greet("Nitu")
# Out:
# Hello Nitu

# %%
fruits = ["apple", "banana", "mango"]

for n in fruits:
    print(n)
# Out:
# apple
# banana
# mango

# %%
for n in "python":
    print(n)
# Out:
# p
# y
# t
# h
# o
# n

# %%
#break (break the loop) / continue (skip no.and continue)
for i in range(1, 6):
    if i == 5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4

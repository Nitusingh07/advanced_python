# %%
#numeric
# integer
a=10
print(a)
print (type(a))
# Out:
# 10
# <class 'int'>

# %%
a=10.0
print (a)
print (type(a))
# Out:
# 10.0
# <class 'float'>

# %%
#string - ordered sequence of character 
#single line denoted by ' ' $ " "
#multiline denoted by "' "'
#index and immutable 
s= ""  #empty string
print (s)
print (type (s))
# Out:
# <class 'str'>

# %%
s= "decode"
print (s)
print (type(s))
print (s[0])
s[0]="z"
print (s)
# Out:
# decode
# <class 'str'>
# d
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 print (type(s))
#       4 print (s[0])
# ----> 5 s[0]="z"
#       6 print (s)
#
# TypeError: 'str' object does not support item assignment

# %%
s= '''   hello
      welcome to
      bhopal 
      guys '''
print(s)
# Out:
#    hello
#       welcome to
#       bhopal
#       guys

# %%
#list --collection of elememt 
#it is denoted by [] with csv
#indexed ,ordered,mutuable and hetrogenious in nature 
l=[] # empty list 
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[10,20,30,"decode",10.5]
print(l)
print(l[3]) # index 
l[0] ="bhopal"
print(l)
# Out:
# [10, 20, 30, 'decode', 10.5]
# decode
# ['bhopal', 20, 30, 'decode', 10.5]

# %%
#tuple - collection of element 
#denoted by () csv 
#ordered ,index,immutable ,hetrogenios
t=()
print(t)
print(type(t))[]
# Out:
#   Cell In[12], line 6
#     print(type(t))[]
#                    ^
# SyntaxError: invalid syntax

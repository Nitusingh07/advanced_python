# %%
i=1
while i <= 10:
    print(i*3)
    i+=1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
i=1
while i <= 10:
    print(i**2)
    i+=1
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

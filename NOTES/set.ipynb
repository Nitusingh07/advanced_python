# %%
s=set()
print(type(s))
# Out:
# <class 'set'>

# %%
s={1,2,4.5,"hello"}
print(type(s))
# Out:
# <class 'set'>

# %%
s={1,2,4.5,"hello"}
for i in s :
    print(i)
# Out:
# 1
# 2
# 4.5
# hello

# %%
s={1,2,4.5,"hello"}
s.add(4)
print(s)
# Out:
# {1, 2, 4.5, 4, 'hello'}

# %%
s={1,2,4.5,"hello"}
s.remove(1)
print(s)
# Out:
# {2, 4.5, 'hello'}

# %%
s={0,3,1,2,4.5,"hello"}
print(s.pop())
print(s)
# Out:
# 0
# {1, 2, 3, 4.5, 'hello'}

# %%
s={1,2,4.5,"hello"}
s.clear()
print(s)
# Out:
# set()

# %%
#dicard # no error 
s={10,20,"hello",10.5,100,200,10}
s.discard(1000)
print(s)
# Out:
# {10.5, 100, 20, 200, 'hello', 10}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}
print (s1|s2)  #union
print (s1&s2) #intersection
print (s1-s2) #difference
print (s1^s2)  #symmetric diffrence
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {1, 2, 3, 6, 7, 8}
